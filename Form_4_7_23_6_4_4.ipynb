# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=2
t1=1

for MM in [[7,8],[28,32]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,4,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 7 modulo 8
# 256
# 64
# 48
# 48
# Trying: 0
# The transformations are:
# ----------------------------------
# [-2 -1 -1]
# [ 0 -1 -3]
# [ 0 -1  1]
# ----------------------------------
# [-1  0  0]
# [ 0 -1  0]
# [ 0  0  1]
# ----------------------------------
# [ 1/2 -1/4  1/4]
# [   0  1/4 -3/4]
# [   0  1/4  1/4]
# #############################
# 28 modulo 32
# 2048
# 512
# 48
# 48
# Trying: 0
# Trying: 1
# Trying: 2
# Trying: 3
# Trying: 4
# Trying: 5
# Trying: 6
# Trying: 7
# Trying: 8
# Trying: 9
# Trying: 10
# Trying: 11
# Trying: 12
# Trying: 13
# Trying: 14
# Trying: 15
# Trying: 16
# Trying: 17
# Trying: 18
# Trying: 19
# Trying: 20
# The transformations are:
# ----------------------------------
# [   0   -2    2]
# [   0   -1   -3]
# [  -1 -1/2 -1/2]
# ----------------------------------
# [-1  0  0]
# [ 0  1  0]
# [ 0  0 -1]
# ----------------------------------
# [-1/8  1/4    1]
# [ 3/8 -1/4    0]
# [-1/8 -1/4    0]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=1
t1=1

for MM in [[4,32]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,4,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 4 modulo 32
# 4096
# 512
# 48
# 48
# Trying: 0
# Trying: 1
# Trying: 2
# Trying: 3
# Trying: 4
# Trying: 5
# Trying: 6
# Trying: 7
# Trying: 8
# Trying: 9
# Trying: 10
# Trying: 11
# Trying: 12
# Trying: 13
# Trying: 14
# Trying: 15
# Trying: 16
# Trying: 17
# Trying: 18
# Trying: 19
# Trying: 20
# The transformations are:
# ----------------------------------
# [   0   -2    2]
# [   0   -1   -3]
# [  -1 -1/2 -1/2]
# ----------------------------------
# [ 1/8  1/4   -1]
# [-3/8 -1/4    0]
# [ 1/8 -1/4    0]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=2
t1=1/4

for MM in [[24,32],[32,256]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,4,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 24 modulo 32
# 2048
# 64
# 48
# 48
# Trying: 0
# The transformations are:
# ----------------------------------
# [  -1 -1/2 -1/2]
# [   0 -1/2 -3/2]
# [   0 -1/2  1/2]
# ----------------------------------
# [   0    0   -2]
# [   0   -1    0]
# [-1/2    0    0]
# ----------------------------------
# [-1/4 -1/2    2]
# [ 3/4  1/2    0]
# [-1/4  1/2    0]
# #############################
# 32 modulo 256
# 131072
# 4096
# 48
# 48
# Trying: 0
# Trying: 1
# Trying: 2
# Trying: 3
# Trying: 4
# The transformations are:
# ----------------------------------
# [-1/2 -5/4 -5/4]
# [-1/2  1/4 -3/4]
# [-1/4 -1/8  7/8]
# ----------------------------------
# [-1  0  0]
# [ 0 -1  0]
# [ 0  0  1]
# ----------------------------------
# [ 1/8  5/4 -5/4]
# [ 5/8 -3/4 -1/4]
# [ 1/8  1/4  3/4]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=1
t1=1

for MM in [[40,64]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,1,8,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 40 modulo 64
# 16384
# 2048
# 48
# 48
# Trying: 0
# The transformations are:
# ----------------------------------
# [  -2   -1   -1]
# [   0   -2    2]
# [   0 -1/2 -3/2]
# ----------------------------------
# [-1/2  1/8  1/2]
# [   0 -3/8 -1/2]
# [   0  1/8 -1/2]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=1
t1=1/16

for MM in [[0,128]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,4,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 0 modulo 128
# 16384
# 32
# 48
# 48
# Trying: 0
# The transformations are:
# ----------------------------------
# [-1/2 -1/4 -1/4]
# [   0 -1/4 -3/4]
# [   0 -1/4  1/4]
# ----------------------------------
# [-2  1  1]
# [ 0 -1 -3]
# [ 0 -1  1]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=1
t1=1

for MM in [[48,128],[80,128]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,16,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 48 modulo 128
# 32768
# 8192
# 16
# 16
# Trying: 0
# Trying: 1
# Trying: 2
# Trying: 3
# Trying: 4
# The transformations are:
# ----------------------------------
# [   0   -2    2]
# [   0   -1   -3]
# [-1/2 -1/4 -1/4]
# ----------------------------------
# [ 1/8  1/4   -2]
# [-3/8 -1/4    0]
# [ 1/8 -1/4    0]
# #############################
# 80 modulo 128
# 32768
# 8192
# 16
# 16
# Trying: 0
# Trying: 1
# Trying: 2
# Trying: 3
# Trying: 4
# The transformations are:
# ----------------------------------
# [   0   -2    2]
# [   0   -1   -3]
# [-1/2 -1/4 -1/4]
# ----------------------------------
# [ 1/8  1/4   -2]
# [-3/8 -1/4    0]
# [ 1/8 -1/4    0]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=1
t1=1/4

for MM in [[64,128]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,16,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 64 modulo 128
# 16384
# 512
# 16
# 16
# Trying: 0
# The transformations are:
# ----------------------------------
# [  -1 -1/2 -1/2]
# [   0 -1/2 -3/2]
# [   0 -1/4  1/4]
# ----------------------------------
# [  -1  1/2    1]
# [   0 -1/2   -3]
# [   0 -1/2    1]

# %%
# %run CombinatorialTernaryFunctions.ipynb

parts=2
t1=1/16

for MM in [[96,128]]:
    m1=MM[0]
    M1=MM[1]
    print('#############################')
    print(m1,'modulo',M1)
    f1=[4,7,23,6,4,4] 
    f2=[1,2,4,0,0,0]
    k=4
    m2=m1*t1
    M2=M1*t1

    F1=SetFinder(M1,m1,f1,prim=1)
    print(len(F1))

    F2=SetFinder(M2,m2,f2,prim=1)
    print(len(F2))

    if len(F1)==0 and len(F2)==0:
        print('Both are zeros!')


    if len(F1)>0 and len(F2)>0:
        result=TRS_Find(f1,m1,M1,f2,k,t1,F1,F2,parts)
        print('The transformations are:')
        for T in result:
            print('----------------------------------')
            print(T)
# Out:
# #############################
# 96 modulo 128
# 16384
# 64
# 48
# 48
# Trying: 0
# The transformations are:
# ----------------------------------
# [-1/2 -1/4 -1/4]
# [   0 -1/4 -3/4]
# [   0 -1/4  1/4]
# ----------------------------------
# [   0    0   -2]
# [   0   -1    0]
# [-1/2    0    0]
# ----------------------------------
# [-1/2   -1    4]
# [ 3/2    1    0]
# [-1/2    1    0]

# %%
# %run CombinatorialTernaryFunctions.ipynb
f1=[4,7,23,6,4,4] 
for MM in [[1,4],[2,4],[3,8],[12,32],[20,32],[8,64],[16,128],[112,128],[160,256]]:
    m1=MM[0]
    M1=MM[1]
    F1=SetFinder(M1,m1,f1,prim=1)
    print('if',m1,'modulo',M1,'then',len(F1))
# Out:
# if 1 modulo 4 then 0
# if 2 modulo 4 then 0
# if 3 modulo 8 then 0
# if 12 modulo 32 then 0
# if 20 modulo 32 then 0
# if 8 modulo 64 then 0
# if 16 modulo 128 then 0
# if 112 modulo 128 then 0
# if 160 modulo 256 then 0
